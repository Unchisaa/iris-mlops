# %%
# Declare variables
REPO_GIT = "Unchisaa/iris-mlops.git"
GITHUB_TOKEN = "ghp_7myembpivfen7ejb8yybik78guytpr0mibhc"
GITHUB_HTTPS = f"https://{GITHUB_TOKEN}@github.com/{REPO_GIT}"

# Clone git repository
# !git clone $GITHUB_HTTPS

# %cd iris-mlops
# Out:
# Cloning into 'iris-mlops'...
# ...
# /content/iris-mlops

# %%
# Configure Git identity (session-only)
# !git config --global user.name "Unchisa"
# !git config --global user.email "66051198@kmitl.ac.th"

# %%
# Install and Initialize DVC

# !pip install --quiet dvc[gdrive]
# !dvc init -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.3/77.3 kB 6.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 438.8/438.8 kB 21.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 3.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 kB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 12.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 210.0/210.0 kB 17.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.6/118.6 kB 9.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.2/73.2 kB 5.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 49.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 461.0/461.0 kB 28.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.9/374.9 kB 28.8 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
import os

# Mount Google Drive
drive.mount('/content/drive')

# Create the DVC remote folder in Drive
remote_path = "/content/drive/MyDrive/mlops-workshop"
os.makedirs(remote_path, exist_ok=True)
print(f"DVC remote folder exists at: {remote_path}")

# Register a new remote under DVC’s configuration
# !dvc remote add -d mydrive {remote_path}
# Out:
# Mounted at /content/drive
# DVC remote folder exists at: /content/drive/MyDrive/mlops-workshop
# Setting 'mydrive' as a default remote.

# %%
# Commit and push your DVC setup
# !git add .dvc .gitignore
# !git commit -m "chore: init DVC and configure GDrive remote"
# !git push -u origin main
# Out:
# fatal: pathspec '.gitignore' did not match any files
# [main (root-commit) 7617f15] chore: init DVC and configure GDrive remote
#  3 files changed, 6 insertions(+)
#  create mode 100644 .dvc/.gitignore
#  create mode 100644 .dvc/config
#  create mode 100644 .dvcignore
# fatal: could not read Password for 'https://ghp_7myembpivfen7ejb8yybik78guytpr0mibhc@github.com': No such device or address

# %%
# Copy notebook from Google Drive to working directory
# !cp '/content/drive/MyDrive/Colab Notebooks/mlops-1.ipynb' .

# Add notebook to Git
# !git add mlops-1.ipynb
# !git commit -m "feat: add Colab notebook to project"
# !git push
# Out:
# [main ae3af24] feat: add Colab notebook to project
#  1 file changed, 1 insertion(+)
#  create mode 100644 mlops-1.ipynb
# fatal: could not read Password for 'https://ghp_7myembpivfen7ejb8yybik78guytpr0mibhc@github.com': No such device or address
